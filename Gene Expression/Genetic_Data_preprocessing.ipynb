# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ### 0. Data Pre-processing and Cleaning

# %%
#reading the data
# genotype_data = pd.read_csv('data/genotype.csv')
# proteomics_data = pd.read_csv('data/proteomics.csv')
gene_expression_data = pd.read_csv('data/gene-expression.csv')
# mri_data = pd.read_csv('data/mri.csv')
# metabolomics_data = pd.read_csv('data/metabolomics.csv')

# %%
genotype_data
# Out:
#     Subject_ID  Sex     PC1     PC2      PC3      PC4      PC5      PC6  \
# 0     DCR00003  2.0  0.0107  0.0286   0.0197  -0.0194   0.0059       26
# 1     DCR00004  1.0  0.0109  0.0258   0.0167  -0.0104   0.0069  -0.0061
# 2     DCR00005  2.0  0.0131  0.0225   0.0117  -0.0087  -0.0085      -24
# 3     DCR00006  2.0  0.0084  0.0279   0.0137  -0.0148  -0.0096  -0.0036
# 4     DCR00009  2.0  0.0088  0.0275   0.0137  -0.0178  -0.0104  -0.0052
# ..         ...  ...     ...     ...      ...      ...      ...      ...
# 987  TLSMCI605  2.0  0.0223  0.0114  -0.0218  -0.0188   0.0113  -0.0014
# 988  TLSMCI609  2.0  0.0189  0.0148      -14  -0.0042   0.0461  -0.0258
# 989  TLSMCI610  1.0  0.0192  0.0161  -0.0094  -0.0192   0.0398  -0.0137
# 990  TLSMCI611  2.0  0.0202  0.0159       -9   0.0032   0.0689   0.0069
# 991  TLSMCI613  1.0  0.0229  0.0075  -0.0231   0.0021   0.0509  -0.0045
#
#          PC7      PC8      PC9     PC10
# 0    -0.0087  -0.0331  -0.0026  -0.0203
# 1    -0.0168  -0.0043   0.0151       23
# 2          5   0,0007   0.0178  -0.0119
# 3     0.0126   0.0123  -0.0017  -0.0117
# 4    -0.0082  -0.0286       16  -0.0169
# ..       ...      ...      ...      ...
# 987  -0.0079  -0.0107  -0.0024   0.0306
# 988  -0.0218  -0.0157  -0.0025       16
# 989   0,0004   0.0196  -0.0027  -0.0151
# 990  -0.0104  -0.0035  -0.0017  -0.0048
# 991   0.0136  -0.0011  -0.0181   0.0071
#
# [992 rows x 12 columns]

# %%
proteomics_data
# Out:
#     Subject_ID Diagnosis     Sex   Age  APOE  MMSE   P0C0L5  P03951  Q9Y4X3  \
# 0     DCR00001        AD  Female  80.0  E3E4  21.0   3716.1  2705.5   908.1
# 1     DCR00007        AD    Male  80.0  E3E4  24.0   5676.7  3217.3   869.1
# 2     DCR00023        AD  Female  88.0  E3E3   NaN   6935.7  2457.9   848.7
# 3     DCR00024        AD  Female  80.0  E3E4   NaN   4940.4  2779.3   888.9
# 4     DCR00025        AD    Male  75.0  E4E4   NaN   9293.7  2199.7   782.2
# ..         ...       ...     ...   ...   ...   ...      ...     ...     ...
# 893  THSMCI062        AD    Male  73.0   NaN  20.0  11673.0  2234.2   843.2
# 894  THSMCI064       MCI    Male  80.0  E3E4  28.0   7606.8  2815.7   893.8
# 895  THSMCI064        AD    Male  80.0  E3E4  22.0   4941.0  2734.2   892.1
# 896  THSMCI065       MCI    Male  76.0  E3E3  29.0  13515.5  2013.5   865.0
# 897  THSMCI065       MCI    Male  77.0  E3E3  25.0   6244.5  1695.3   898.0
#
#      P39060  ...  P23396  Q86VB7  Q12884  Q8IXJ6  Q13813  Q08945  P09493  \
# 0    5013.4  ...   842.5  2916.3  4790.8  1204.7   596.2   948.7   965.3
# 1    6088.9  ...   534.2  3156.5  5171.8  1796.0   555.5   908.1   933.6
# 2    7136.7  ...   530.4  2948.8  3801.5  1161.2   557.2  1070.1   984.7
# 3    6622.9  ...   652.7  2600.1  2882.3  1840.7   520.3   901.3   940.7
# 4    6391.1  ...   410.4  2045.8  3141.5   832.8   494.1   896.6   900.9
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 893  4923.5  ...  1031.6  2380.4  2213.6  1397.2   457.3   920.7   982.7
# 894  5035.3  ...  1333.7  1659.9  2264.9  1283.5   483.9  1197.9   863.0
# 895  5240.2  ...  1078.8  1832.6  2959.2  1597.6   541.8  1281.8   843.8
# 896  7424.7  ...  1816.2  2861.4  2809.6  1897.8   567.2  1013.0   943.1
# 897  6436.7  ...  2075.0  2900.0  3152.2  1504.6   503.6  1138.4   936.7
#
#       P07478  P04818  P98066
# 0    26393.3   714.4  1289.0
# 1    45037.9   762.2  1370.5
# 2    38593.2   825.6  1328.2
# 3    40413.4  6286.7   992.4
# 4    22241.0   729.2   997.0
# ..       ...     ...     ...
# 893  17674.7   560.3  1137.6
# 894  23074.0   561.0  1142.0
# 895  23816.7   565.0  1161.1
# 896  37664.4   629.0  1209.7
# 897  33408.0   654.1  1245.5
#
# [898 rows x 1022 columns]

# %%
gene_expression_data
# Out:
#     Subject_ID Diagnosis     Sex   Age  APOE  MMSE  0..gjSdbqnr.rUSTBI  \
# 0     DCR00001        AD  Female  80.0  E3E4  21.0            6.186378
# 1     DCR00004       MCI    Male  78.0  E4E4  27.0            6.577102
# 2     DCR00009       CTL  Female  69.0  E3E3  30.0            6.802756
# 3     DCR00013       CTL    Male  82.0  E3E3  30.0            6.656712
# 4     DCR00014       CTL  Female  75.0  E2E3  30.0            7.072468
# ..         ...       ...     ...   ...   ...   ...                 ...
# 686  TLSMCI607       MCI  Female  72.0  E3E3  29.0            9.530581
# 687  TLSMCI608       MCI    Male  73.0  E3E3  28.0            8.189603
# 688  TLSMCI609       MCI  Female  63.0  E3E3  28.0            7.465088
# 689  TLSMCI611       MCI  Female  78.0  E3E3  30.0            6.531374
# 690  TLSMCI612       MCI  Female  79.0  E3E3  28.0            8.265589
#
#      0.PRu.vXrqQjlN4p9I  00K3OeGXV631V5_6eA  00buPhOysV5Rpc5VF4  ...  \
# 0              7.319845            6.809282            6.368337  ...
# 1              7.568351            6.891144            6.087313  ...
# 2              7.363365            6.859408            6.228749  ...
# 3              7.076369            6.755748            7.063700  ...
# 4              7.182262            6.955473            6.547903  ...
# ..                  ...                 ...                 ...  ...
# 686            8.861265            9.030972            8.165198  ...
# 687            8.830422            8.894175            8.744474  ...
# 688            7.654655            6.625375            5.621634  ...
# 689            7.379502            7.156618            6.759388  ...
# 690            9.378604            9.196883            8.971024  ...
#
#      xu.S6OENiSSCDruXFc  xu3n8ix_RpCpNPRKhc  xuBm5ckgidWRNTl.gQ  \
# 0              6.815122            6.852799            8.033687
# 1              6.692184            6.339804            7.574675
# 2              7.174704            6.573524            7.933956
# 3              6.761184            7.107434            8.491854
# 4              6.620391            6.613991            7.912094
# ..                  ...                 ...                 ...
# 686            8.286385            7.747066           10.146485
# 687            8.448899            8.365566            9.213112
# 688            6.920061            5.985924            8.401238
# 689            7.009826            6.595556            8.236181
# 690            8.276048            8.160318            8.993411
#
#      xuNOUeR1JerhIuIV7c  xud4v2r3nXECBua55o  xvHfVEL1fC35XJ7neU  \
# 0             13.580622            7.062255            5.461009
# 1             13.429012            6.676346            5.930943
# 2             13.429234            7.461987            6.011960
# 3             13.432100            6.761740            6.542947
# 4             13.739312            7.759156            5.805024
# ..                  ...                 ...                 ...
# 686           14.587858            9.362908            8.300646
# 687           14.543860            8.938056            7.596111
# 688           13.502124            7.484527            5.863061
# 689           13.885397            7.842649            6.495667
# 690           14.560314            9.186235            7.846456
#
#      xve7nuGHtAizelOmhE  xvrrv4q_nIDgJej.uU  xws9e3UChad1OnXmXY  \
# 0              7.381171           10.610103            8.422317
# 1              7.822177           11.097957            8.187505
# 2              7.690588           11.176248            7.925652
# 3              7.755136           10.698500            8.320917
# 4              7.633530           10.349654            8.067928
# ..                  ...                 ...                 ...
# 686            9.280271           11.109507           10.233133
# 687            9.157521           12.022353            9.681454
# 688            7.801721           11.243535            7.944169
# 689            7.589291           10.492283            8.058627
# 690            8.948924           12.243905            9.612958
#
#      xz1S1tKD.sgqfTuesU
# 0              7.248468
# 1              7.347366
# 2              7.393746
# 3              6.899011
# 4              7.187345
# ..                  ...
# 686            8.534285
# 687            8.074346
# 688            7.447744
# 689            7.275180
# 690            8.029585
#
# [691 rows x 5218 columns]

# %%
#get subject ID in each dataset
# genotype_data_subject_id = genotype_data['Subject_ID']
# proteomics_data_subject_id = proteomics_data['Subject_ID']
gene_expression_data_subject_id = gene_expression_data['Subject_ID']
# mri_data_subject_id = mri_data['Subject_ID']
# metabolomics_data_subject_id = metabolomics_data['Subject_ID']

# %%
print(len(gene_expression_data_subject_id))
# Out:
# 691

# %% [markdown]
# #### Imputing Missing Values

# %%
def impute_missing_values(data):
    #impute missing values with the median
    continuous_imputer = SimpleImputer(strategy='mean')
    categorical_imputer = SimpleImputer(strategy='most_frequent')
    continuous_columns = data.select_dtypes(include=np.number).columns
    categorical_columns = data.select_dtypes(include='object').columns
    data[continuous_columns] = continuous_imputer.fit_transform(data[continuous_columns])
    data[categorical_columns] = categorical_imputer.fit_transform(data[categorical_columns])
    return data

# %%
# genotype_data = impute_missing_values(genotype_data)
# proteomics_data = impute_missing_values(proteomics_data)
gene_expression_data = impute_missing_values(gene_expression_data)
# mri_data = impute_missing_values(mri_data)
# metabolomics_data = impute_missing_values(metabolomics_data)

# %% [markdown]
# #### Scaling Continuous Values

# %%
def scale_data(data):
    scaler = MinMaxScaler()
    #get continuous columns
    continuous_columns = data.select_dtypes(include=np.number).columns
    #remove age column if it exists
    if 'Age' in continuous_columns:
        continuous_columns = continuous_columns.drop(['Age'])
    data[continuous_columns] = scaler.fit_transform(data[continuous_columns])
    return data

# %%
# genotype_data = scale_data(genotype_data)
# proteomics_data = scale_data(proteomics_data)
gene_expression_data = scale_data(gene_expression_data)
# mri_data = scale_data(mri_data)
# metabolomics_data = scale_data(metabolomics_data)

# %% [markdown]
# #### Label Encode Categorical Features

# %%
def label_encode(data):
    #label encode categorical data
    categorical_columns = data.select_dtypes(include='object').columns
    #drop the Subject_ID column and PCA columns from the categorical columns
    if 'Subject_ID' in categorical_columns:
        categorical_columns = categorical_columns.drop('Subject_ID')
    if 'PC1' in categorical_columns:
        categorical_columns = categorical_columns.drop(['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10'])
    #encode categorical data but print the mapping
    for column in categorical_columns:
        print(column)
        data[column], mapping_index = data[column].factorize()
        print(mapping_index)
    return data

# %%
# genotype_data = label_encode(genotype_data)
# proteomics_data = label_encode(proteomics_data)
gene_expression_data = label_encode(gene_expression_data)
# mri_data = label_encode(mri_data)
# metabolomics_data = label_encode(metabolomics_data)
# Out:
# Diagnosis
# Index(['AD', 'MCI', 'CTL'], dtype='object')
# Sex
# Index(['Female', 'Male'], dtype='object')
# APOE
# Index(['E3E4', 'E4E4', 'E3E3', 'E2E3', 'E2E4'], dtype='object')

# %% [markdown]
# #### Merge Dataset

# %%
#find the common columns in all datasets
common_columns = set(genotype_data.columns) & set(proteomics_data.columns) & set(gene_expression_data.columns) & set(mri_data.columns) & set(metabolomics_data.columns)
print(common_columns)
# Out:
# {'Subject_ID'}

# %%
#print number of features in each dataset
print(f"Number of features in Genotype data: {genotype_data.shape[1]}")
print(f"Number of features in Proteomics data: {proteomics_data.shape[1]}")
print(f"Number of features in Gene Expression data: {gene_expression_data.shape[1]}")
print(f"Number of features in MRI data: {mri_data.shape[1]}")
print(f"Number of features in Metabolomics data: {metabolomics_data.shape[1]}")
# Out:
# Number of features in Genotype data: 11
# Number of features in Proteomics data: 1017
# Number of features in Gene Expression data: 5218
# Number of features in MRI data: 137
# Number of features in Metabolomics data: 6220

# %%
#merge the datasets based on the Subject_ID
data = pd.merge(genotype_data, proteomics_data, on='Subject_ID')
data = pd.merge(data, mri_data, on='Subject_ID')
data = pd.merge(data, metabolomics_data, on='Subject_ID')
data = pd.merge(data, gene_expression_data, on='Subject_ID')

# %%
#drop duplicate rows
data = data.drop_duplicates()

# %%
#drop rows with the same Key but keep the first one
data = data.drop_duplicates(subset='Subject_ID', keep='first')

# %%
data
# Out:
#      Subject_ID      PC1      PC2      PC3      PC4      PC5      PC6  \
# 0     KPOADC002  -0.0858  -0.0128  -0.0204  -0.0074   0,0001  -0.0461
# 6     KPOADC006  -0.0846  -0.0142  -0.0142  -0.0051  -0.0112  -0.0254
# 8     KPOADC007  -0.0865  -0.0143  -0.0158  -0.0242  -0.0319   0.0826
# 14    KPOADC008  -0.0605  -0.0191       13       33  -0.0256   0.1634
# 20    KPOADC013  -0.0838  -0.0141  -0.0082  -0.0145   0.0316  -0.0482
# ...         ...      ...      ...      ...      ...      ...      ...
# 1296  THSMCI016   0.0122  -0.0554   0.0049   0.0054   0.0016   0,0009
# 1299  THSMCI017   0.0069  -0.0513   0.0108   0.0147   0.0025   0.0036
# 1302  THSMCI060   0.0112  -0.0546   0.0058   0.0225   0.0092  -0.0363
# 1308  THSMCI064   0.0135  -0.0574  -0.0044       -2   0.0141  -0.0033
# 1312  THSMCI065   0.0011  -0.0498   0.0126   0.0303   0.0014       -4
#
#           PC7      PC8      PC9  ... xu.S6OENiSSCDruXFc  xu3n8ix_RpCpNPRKhc  \
# 0      0,0009     0.01   0.0586  ...           0.700966            0.790422
# 6     -0.0219   0.0795   0.0101  ...           0.748627            0.753470
# 8     -0.0668  -0.0357  -0.1104  ...           0.921665            0.848276
# 14     0.0757  -0.0284   0.1533  ...           0.802631            0.961107
# 20     0.0442   0.0257  -0.1075  ...           0.731237            0.769707
# ...       ...      ...      ...  ...                ...                 ...
# 1296  -0.0398      -18   0.0117  ...           0.728107            0.752802
# 1299  -0.0193   0.0043  -0.0102  ...           0.738299            0.743400
# 1302  -0.0032   0.0126  -0.0011  ...           0.710354            0.844926
# 1308  -0.0299  -0.0281   0.0392  ...           0.628193            0.951722
# 1312      -12  -0.0313  -0.0067  ...           0.623643            0.928073
#
#       xuBm5ckgidWRNTl.gQ  xuNOUeR1JerhIuIV7c  xud4v2r3nXECBua55o  \
# 0               0.616192            0.814075            0.895631
# 6               0.552693            0.747051            0.704070
# 8               0.290235            0.606354            0.632002
# 14              0.387882            0.744785            0.571144
# 20              0.379646            0.891139            0.674242
# ...                  ...                 ...                 ...
# 1296            0.655550            0.887384            0.911735
# 1299            0.852921            0.789538            0.796667
# 1302            0.643897            0.833653            0.718570
# 1308            0.491185            0.811180            0.851986
# 1312            0.689269            0.829530            0.824156
#
#       xvHfVEL1fC35XJ7neU  xve7nuGHtAizelOmhE  xvrrv4q_nIDgJej.uU  \
# 0               0.929776            0.763615            0.607193
# 6               0.835542            0.963344            0.759021
# 8               0.639545            0.900243            1.000000
# 14              0.829212            0.819158            0.853226
# 20              0.816044            0.726850            0.898484
# ...                  ...                 ...                 ...
# 1296            0.796723            0.695765            0.507369
# 1299            0.749100            0.649148            0.515005
# 1302            0.828828            0.580639            0.633924
# 1308            0.936146            0.688535            0.549367
# 1312            0.778257            0.688354            0.510799
#
#       xws9e3UChad1OnXmXY  xz1S1tKD.sgqfTuesU
# 0               0.830143            0.833734
# 6               0.884777            0.542998
# 8               0.661482            0.388760
# 14              0.733976            0.657866
# 20              0.734872            0.637025
# ...                  ...                 ...
# 1296            0.860978            0.705117
# 1299            0.940402            0.520334
# 1302            0.773751            0.630178
# 1308            0.754315            0.653483
# 1312            0.852247            0.750686
#
# [190 rows x 12599 columns]

# %%
#save the data
gene_expression_data.to_csv('data/gene_expression_processed.csv', index=False)
