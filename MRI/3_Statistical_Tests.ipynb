# %%
import pandas as pd
from scipy.stats import chi2_contingency 
from scipy import stats
import numpy as np
import statsmodels.stats.api as sms
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
data = pd.read_csv('../data/MRI_data_2.csv')

# %%
data.head()
# Out:
#    Visit  Site  Sex   Age  APOE  MMSE  lh_bankssts_thickness  \
# 0      0     0    0  86.0     0  20.0                  2.224
# 1      1     0    0  86.0     0  16.0                  2.140
# 2      2     0    0  87.0     0  21.0                  2.248
# 3      0     0    0  68.0     0  26.0                  1.971
# 4      1     0    0  68.0     0  25.0                  2.066
#
#    rh_bankssts_thickness  lh_caudalanteriorcingulate_thickness  \
# 0                  2.249                                 2.883
# 1                  2.092                                 2.991
# 2                  2.343                                 3.088
# 3                  2.018                                 2.394
# 4                  2.112                                 2.353
#
#    rh_caudalanteriorcingulate_thickness  ...  rhCortexVol  \
# 0                                 2.172  ...  171640.3232
# 1                                 2.038  ...  162216.0014
# 2                                 2.157  ...  168541.5319
# 3                                 2.336  ...  182858.7837
# 4                                 2.285  ...  182255.2786
#
#    lhCerebralWhiteMatterVol  SubCortGrayVol    MaskVol  BrainSegVol-to-eTIV  \
# 0               184191.9575         40324.0  1361906.0             0.664587
# 1               192981.9801         38797.0  1319352.0             0.659338
# 2               189605.4005         39722.0  1342921.0             0.660968
# 3               199432.8506         45318.0  1515148.0             0.652202
# 4               195086.1362         44336.0  1508917.0             0.643059
#
#    MaskVol-to-eTIV  lhSurfaceHoles  rhSurfaceHoles   Subject_ID  Diagnosis
# 0         0.977432            24.0            13.0  KPOADC001_1          0
# 1         0.941138            23.0            17.0  KPOADC001_2          0
# 2         0.959201            30.0            24.0  KPOADC001_5          0
# 3         0.976865            22.0            21.0  KPOADC002_1          0
# 4         0.968317            20.0             9.0  KPOADC002_2          0
#
# [5 rows x 128 columns]

# %% [markdown]
# ### 3. Statistical Tests

# %% [markdown]
# #### Chi Squared Tests

# %% [markdown]
# ##### H₀ — that the 2 categorical variables being compared are independent of each other (no association)
# ##### H₁ — that the 2 categorical variables being compared are dependent on each other (association).

# %% [markdown]
# ##### 1. Gender and AD Diagnosis

# %%
data['Sex'] = data['Sex'].replace({0:'Female', 1:'Male'})
data['Diagnosis'] = data['Diagnosis'].replace({0:'AD', 1:'CTL', 2:'MCI'})  

chi = pd.crosstab(data.Sex, data.Diagnosis,margins=True)
print(chi)

obs = np.array([chi.iloc[0][0:-1].values,chi.iloc[1][0:-1].values])
chi_squared = stats.chi2_contingency(obs, correction=False)
print("\n(X^2, p, df):",chi_squared[0:3])

print("\nConclusion:")
if(chi_squared[1] < 0.05):
    print("At 5% significance level, we fail to reject Ha which means there is sufficient evidence to suggest that there is an association between AD diagnosis and the gender feature")
else:
    print("At 5% significance level, we fail to reject Ho which means there is sufficient evidence to suggest that there is no association between AD diagnosis and the gender feature")
# Out:
# Diagnosis   AD  CTL  MCI   All
# Sex
# Female     227  184  167   578
# Male       117  150  164   431
# All        344  334  331  1009
#
# (X^2, p, df): (17.620430700492648, 0.00014920112198050345, 2)
#
# Conclusion:
# At 5% significance level, we fail to reject Ha which means there is sufficient evidence to suggest that there is an association between AD diagnosis and the gender feature

# %% [markdown]
# ##### 2. APOE and AD Diagnosis

# %%
data['APOE'] = data['APOE'].replace({0:'E4E4', 1:'E3E3', 2:'E3E4', 3:'E2E3', 4:'E2E4', 5:'E2E2'})
data['Diagnosis'] = data['Diagnosis'].replace({0:'AD', 1:'CTL', 2:'MCI'})  

chi = pd.crosstab(data.APOE, data.Diagnosis,margins=True)
print(chi)
obs = np.array([chi.iloc[1][0:-1].values,chi.iloc[4][0:-1].values])
chi_squared = stats.chi2_contingency(obs, correction=False)
print("\n(X^2, p, df):",chi_squared[0:3])

print("\nConclusion:")
if(chi_squared[1] < 0.05):
    print("At 5% significance level, we fail to reject Ha which means there is sufficient evidence to suggest that there is an association between AD diagnosis and the APOE feature")
else:
    print("At 5% significance level, we fail to reject Ho which means there is sufficient evidence to suggest that there is no association between AD diagnosis and the APOE feature")
# Out:
# Diagnosis   AD  CTL  MCI   All
# APOE
# E2E2         0    0    2     2
# E2E3        12   49   27    88
# E2E4         3    7    6    16
# E3E3       128  177  184   489
# E3E4       140   89   98   327
# E4E4        61   12   14    87
# All        344  334  331  1009
#
# (X^2, p, df): (33.02342663561697, 6.746119334452304e-08, 2)
#
# Conclusion:
# At 5% significance level, we fail to reject Ha which means there is sufficient evidence to suggest that there is an association between AD diagnosis and the APOE feature

# %% [markdown]
# ##### 3. MMSE and AD Diagnosis

# %%
#create new catgeory based on MMSE score, q1, q2, q3, q4
data['MMSE_Cat'] = pd.cut(data['MMSE'], bins=[6,19,24.5,30], labels=['low','moderate','high'])

# %%
data['Diagnosis'] = data['Diagnosis'].replace({0:'AD', 1:'CTL', 2:'MCI'})  

chi = pd.crosstab(data.MMSE_Cat, data.Diagnosis,margins=True)
print(chi)

obs = np.array([chi.iloc[0][0:-1].values,chi.iloc[1][0:-1].values])
chi_squared = stats.chi2_contingency(obs, correction=True)
print("\n(X^2, p, df):",chi_squared[0:3])

print("\nConclusion:")
if(chi_squared[1] < 0.05):
    print("At 5% significance level, we fail to reject Ha which means there is sufficient evidence to suggest that there is an association between AD diagnosis and the MMSE score")
else:
    print("At 5% significance level, we fail to reject Ho which means there is sufficient evidence to suggest that there is no association between AD diagnosis and the MMSE score")
# Out:
# Diagnosis   AD  CTL  MCI   All
# MMSE_Cat
# low        130    0    6   136
# moderate   120    2   34   156
# high        93  332  291   716
# All        343  334  331  1008
#
# (X^2, p, df): (20.727375565610863, 3.1557862803324876e-05, 2)
#
# Conclusion:
# At 5% significance level, we fail to reject Ha which means there is sufficient evidence to suggest that there is an association between AD diagnosis and the MMSE score

# %% [markdown]
# ### Confidence Interval

# %% [markdown]
# #### 1. Gender and Diagnosis

# %%
#95% confidence interval for difference in mean
data['Sex'] = data['Sex'].replace({'Female':0, 'Male':1})
data['Diagnosis'] = data['Diagnosis'].replace({'AD':0, 'CTL':1, 'MCI':2})  
female = data.query('Sex == 0')
male = data.query('Sex == 1')

cm = sms.CompareMeans(sms.DescrStatsW(female['Diagnosis']), sms.DescrStatsW(male['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

# print("\nGiven that the value of zero is included in the interval, this suggest that the means of the two population can be assumed equal as there is a difference between them. ")
# Out:
# Confidence Interval for u1-u2:  (-0.31390491144172805, -0.11180499310150058)

# %% [markdown]
# #### 2. APOE and Diagnosis

# %%
#95% confidence interval for difference in mean
data['APOE'] = data['APOE'].replace({'E4E4':0, 'E3E3':1, 'E3E4':2, 'E2E3':3, 'E2E4':4, 'E2E2':5})
e4e4 = data.query('APOE == 0')
e3e3 = data.query('APOE == 1')
e3e4 = data.query('APOE == 2')
e2e3 = data.query('APOE == 3')

print("\nE4E4 vs E3E3")
cm = sms.CompareMeans(sms.DescrStatsW(e4e4['Diagnosis']), sms.DescrStatsW(e3e3['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nE4E4 vs E3E4")
cm = sms.CompareMeans(sms.DescrStatsW(e4e4['Diagnosis']), sms.DescrStatsW(e3e4['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nE4E4 vs E2E3")
cm = sms.CompareMeans(sms.DescrStatsW(e4e4['Diagnosis']), sms.DescrStatsW(e2e3['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nE3E3 vs E3E4")
cm = sms.CompareMeans(sms.DescrStatsW(e3e3['Diagnosis']), sms.DescrStatsW(e3e4['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nE3E3 vs E2E3")
cm = sms.CompareMeans(sms.DescrStatsW(e3e3['Diagnosis']), sms.DescrStatsW(e2e3['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nE3E4 vs E2E3")
cm = sms.CompareMeans(sms.DescrStatsW(e3e4['Diagnosis']), sms.DescrStatsW(e2e3['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))
# Out:
# E4E4 vs E3E3
# Confidence Interval for u1-u2:  (-0.8308284156981052, -0.47867020922256326)
#
# E4E4 vs E3E4
# Confidence Interval for u1-u2:  (-0.5973006956749015, -0.22627834049508685)
#
# E4E4 vs E2E3
# Confidence Interval for u1-u2:  (-0.9213810946183797, -0.4999877664056537)
#
# E3E3 vs E3E4
# Confidence Interval for u1-u2:  (0.12741877891129982, 0.35850080983938015)
#
# E3E3 vs E2E3
# Confidence Interval for u1-u2:  (-0.20961130338707254, 0.09774106728370754)
#
# E3E4 vs E2E3
# Confidence Interval for u1-u2:  (-0.46333321098684943, -0.13445661386719554)

# %%
data['APOE'] = data['APOE'].replace({0:'E4E4', 1:'E3E3', 2:'E3E4', 3:'E2E3', 4:'E2E4', 5:'E2E2'})
data['Diagnosis'] = data['Diagnosis'].replace({0:'AD', 1:'CTL', 2:'MCI'})  

# Group the data by 'APOE' and 'Diagnosis' and count the occurrences
grouped_counts = data[['APOE','Diagnosis','Sex']].groupby(['APOE', 'Diagnosis']).count()

# Rename the 'Sex' column to 'Count' as it now represents the count of occurrences
grouped_counts.rename(columns={'Sex': 'Count'}, inplace=True)

# Calculate the sum of each APOE group
total_counts_per_apoe = grouped_counts.groupby('APOE').transform('sum')

# Calculate the percentage for each APOE-Diagnosis combination
grouped_counts['Percentage'] = (grouped_counts['Count'] / total_counts_per_apoe['Count']) * 100

print(grouped_counts)
# Out:
#                 Count  Percentage
# APOE Diagnosis
# E2E2 MCI            2  100.000000
# E2E3 AD            12   13.636364
#      CTL           49   55.681818
#      MCI           27   30.681818
# E2E4 AD             3   18.750000
#      CTL            7   43.750000
#      MCI            6   37.500000
# E3E3 AD           128   26.175869
#      CTL          177   36.196319
#      MCI          184   37.627812
# E3E4 AD           140   42.813456
#      CTL           89   27.217125
#      MCI           98   29.969419
# E4E4 AD            61   70.114943
#      CTL           12   13.793103
#      MCI           14   16.091954

# %% [markdown]
# Based on the confidence intervals, the differences between certain APOE genotypes suggest the following for Alzheimer's disease (AD) diagnosis:
#
# - E4E4 vs E3E3: The confidence interval does not contain zero, indicating a statistically significant difference between these two genotypes for AD diagnosis. The E4E4 genotype appears to be associated with a higher risk of AD compared to E3E3.
# - E4E4 vs E3E4: The confidence interval does not contain zero, suggesting a significant difference between E4E4 and E3E4 genotypes for AD diagnosis. The E4E4 genotype likely has a higher risk of AD than E3E4.
# - E4E4 vs E2E3: The confidence interval does not contain zero, implying a significant difference between E4E4 and E2E3 genotypes. The E4E4 genotype is likely associated with a higher risk of AD compared to E2E3.
# - E3E3 vs E3E4: The confidence interval does not contain zero, indicating a significant difference between these genotypes for AD diagnosis. The E3E4 genotype may have a higher risk of AD than E3E3.
# - E3E3 vs E2E3 and E3E4 vs E2E3: The confidence intervals contain zero, suggesting no statistically significant difference between these genotype pairs for AD diagnosis.
#
#
# In summary, the presence of the E4 allele, particularly the E4E4 genotype, appears to be associated with a higher risk of Alzheimer's disease compared to other APOE genotypes like E3E3, E3E4, and E2E3.

# %% [markdown]
# #### 3. MMSE and AD

# %%
data['MMSE_Cat'] = pd.cut(data['MMSE'], bins=[6,19,24.5,30], labels=['low','moderate','high'])

# %%
q1 = np.quantile(data['MMSE'], 0)
q2 = np.quantile(data['MMSE'], 0.25)
q3 = np.quantile(data['MMSE'], 0.5)
q4 = np.quantile(data['MMSE'], 0.75)
q5 = np.quantile(data['MMSE'], 1)
print(q1,q2,q3,q4,q5)
# Out:
# 6.0 24.0 27.0 29.0 30.0

# %%
data['Diagnosis'] = data['Diagnosis'].replace({'AD':0, 'CTL':1, 'MCI':2})

# %%
data['MMSE_Cat'] = pd.cut(data['MMSE'], bins=[q1-1,q2,q3,q4,q5], labels=['very low','low','moderate','high'])
very_low = data.query('MMSE_Cat == "very low"')
low = data.query('MMSE_Cat == "low"')
moderate = data.query('MMSE_Cat == "moderate"')
high = data.query('MMSE_Cat == "high"')

print("\nVery Low vs Low")
cm = sms.CompareMeans(sms.DescrStatsW(very_low['Diagnosis']), sms.DescrStatsW(low['Diagnosis']))
print("Confidence Interval for u1-u2: ", str(cm.tconfint_diff(usevar='unequal')))

print("\nVery Low vs Moderate")
cm = sms.CompareMeans(sms.DescrStatsW(very_low['Diagnosis']), sms.DescrStatsW(moderate['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nVery Low vs High")
cm = sms.CompareMeans(sms.DescrStatsW(very_low['Diagnosis']), sms.DescrStatsW(high['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nLow vs Moderate")
cm = sms.CompareMeans(sms.DescrStatsW(low['Diagnosis']), sms.DescrStatsW(moderate['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nLow vs High")
cm = sms.CompareMeans(sms.DescrStatsW(low['Diagnosis']), sms.DescrStatsW(high['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nModerate vs High")
cm = sms.CompareMeans(sms.DescrStatsW(moderate['Diagnosis']), sms.DescrStatsW(high['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))
# Out:
# Very Low vs Low
# Confidence Interval for u1-u2:  (-1.1238439096220614, -0.8651655900144636)
#
# Very Low vs Moderate
# Confidence Interval for u1-u2:  (-1.198711274941612, -0.9915617626010502)
#
# Very Low vs High
# Confidence Interval for u1-u2:  (-0.9101504593009034, -0.7155530418179178)
#
# Low vs Moderate
# Confidence Interval for u1-u2:  (-0.22278888176788636, 0.021525343861748966)
#
# Low vs High
# Confidence Interval for u1-u2:  (0.06476560337954113, 0.2985403951381625)
#
# Moderate vs High
# Confidence Interval for u1-u2:  (0.19479985816128098, 0.36976967826256)

# %% [markdown]
# Based on the confidence intervals comparing different MMSE score bands, this image suggests the following about the relationship between MMSE scores and Alzheimer's disease (AD) diagnosis:
#
# - Very Low vs Low: The confidence interval contains zero, indicating there may not be a statistically significant difference in AD diagnosis between the "Very Low" and "Low" MMSE score bands.
# - Very Low vs Moderate: The confidence interval does not contain zero, suggesting a statistically significant difference between the "Very Low" and "Moderate" MMSE bands for AD diagnosis. The "Very Low" band is likely associated with a higher risk of AD compared to the "Moderate" band.
# - Very Low vs High: The confidence interval does not contain zero, implying a significant difference between the "Very Low" and "High" MMSE bands in terms of AD diagnosis. The "Very Low" band is probably associated with a higher risk of AD compared to the "High" band.
# - Low vs Moderate: The confidence interval contains zero, indicating no statistically significant difference in AD diagnosis between the "Low" and "Moderate" MMSE bands.
# - Low vs High: The confidence interval does not contain zero, suggesting a significant difference between the "Low" and "High" MMSE bands for AD diagnosis. The "Low" band is likely associated with a higher risk of AD compared to the "High" band.
# - Moderate vs High: The confidence interval does not contain zero, implying a significant difference between the "Moderate" and "High" MMSE bands in terms of AD diagnosis. The "Moderate" band is probably associated with a higher risk of AD compared to the "High" band.
#
#
# In summary, lower MMSE scores, particularly in the "Very Low" and "Low" bands, appear to be associated with a higher risk of Alzheimer's disease compared to higher MMSE scores in the "Moderate" and "High" bands.

# %% [markdown]
# ### Hypothesis Testing

# %%
data = pd.read_csv('../data/MRI_data_2.csv')
data
# Out:
#       Visit  Site  Sex   Age  APOE  MMSE  lh_bankssts_thickness  \
# 0         0     0    0  86.0     0  20.0                  2.224
# 1         1     0    0  86.0     0  16.0                  2.140
# 2         2     0    0  87.0     0  21.0                  2.248
# 3         0     0    0  68.0     0  26.0                  1.971
# 4         1     0    0  68.0     0  25.0                  2.066
# ...     ...   ...  ...   ...   ...   ...                    ...
# 1004      0     5    0  72.0     1  29.0                  2.077
# 1005      3     5    0  72.0     1  29.0                  2.128
# 1006      0     5    1  73.0     1  28.0                  2.146
# 1007      3     5    1  73.0     1  28.0                  2.068
# 1008      0     5    0  79.0     1  28.0                  2.480
#
#       rh_bankssts_thickness  lh_caudalanteriorcingulate_thickness  \
# 0                     2.249                                 2.883
# 1                     2.092                                 2.991
# 2                     2.343                                 3.088
# 3                     2.018                                 2.394
# 4                     2.112                                 2.353
# ...                     ...                                   ...
# 1004                  2.212                                 3.181
# 1005                  2.249                                 2.709
# 1006                  2.179                                 2.776
# 1007                  2.183                                 2.793
# 1008                  2.516                                 2.455
#
#       rh_caudalanteriorcingulate_thickness  ...  rhCortexVol  \
# 0                                    2.172  ...  171640.3232
# 1                                    2.038  ...  162216.0014
# 2                                    2.157  ...  168541.5319
# 3                                    2.336  ...  182858.7837
# 4                                    2.285  ...  182255.2786
# ...                                    ...  ...          ...
# 1004                                 2.595  ...  158168.3125
# 1005                                 2.623  ...  160279.0441
# 1006                                 2.353  ...  175083.0216
# 1007                                 2.405  ...  177003.4186
# 1008                                 2.290  ...  178604.5934
#
#       lhCerebralWhiteMatterVol  SubCortGrayVol    MaskVol  \
# 0                  184191.9575         40324.0  1361906.0
# 1                  192981.9801         38797.0  1319352.0
# 2                  189605.4005         39722.0  1342921.0
# 3                  199432.8506         45318.0  1515148.0
# 4                  195086.1362         44336.0  1508917.0
# ...                        ...             ...        ...
# 1004               195236.8035         43989.0  1291996.0
# 1005               193091.3118         43329.0  1254851.0
# 1006               201773.2805         40044.0  1410540.0
# 1007               204008.1402         40428.0  1428442.0
# 1008               202757.2365         43025.0  1335847.0
#
#       BrainSegVol-to-eTIV  MaskVol-to-eTIV  lhSurfaceHoles  rhSurfaceHoles  \
# 0                0.664587         0.977432            24.0            13.0
# 1                0.659338         0.941138            23.0            17.0
# 2                0.660968         0.959201            30.0            24.0
# 3                0.652202         0.976865            22.0            21.0
# 4                0.643059         0.968317            20.0             9.0
# ...                   ...              ...             ...             ...
# 1004             0.694822         1.009026            20.0            14.0
# 1005             0.697605         0.990604            17.0            16.0
# 1006             0.684031         1.032691            35.0            29.0
# 1007             0.685443         1.044901            39.0            34.0
# 1008             0.705282         0.980842            20.0            16.0
#
#          Subject_ID  Diagnosis
# 0       KPOADC001_1          0
# 1       KPOADC001_2          0
# 2       KPOADC001_5          0
# 3       KPOADC002_1          0
# 4       KPOADC002_2          0
# ...             ...        ...
# 1004    TLSMCI607_1          2
# 1005  TLSMCI607_1.5          2
# 1006    TLSMCI608_1          2
# 1007  TLSMCI608_1.5          2
# 1008    TLSMCI612_1          2
#
# [1009 rows x 128 columns]

# %%
import pandas as pd
from scipy import stats

data_no_key = data.drop(columns=['Subject_ID'])
ad = data_no_key.query('Diagnosis == 0')
ctl = data_no_key.query('Diagnosis == 1')
# Perform an independent t-test 
t_stat, p_val = stats.ttest_ind(ad, ctl, axis=0)

significant_features = []
# Iterate over the T-statistics and P-values to print out results for each comparison
for i, (t, p) in enumerate(zip(t_stat, p_val)):
    # print(f"Comparison {i}: T-statistic = {t}, P-value = {p}")
    if p < 0.05:
        print(f"  -> Significant difference detected at comparison {i}")
        print(f"Feature {data_no_key.columns[i]} is significantly different between AD and CTL groups")
        significant_features.append(data_no_key.columns[i])
# Out:
#   -> Significant difference detected at comparison 0
# Feature Visit is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1
# Feature Site is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 2
# Feature Sex is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 3
# Feature Age is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 4
# Feature APOE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 5
# Feature MMSE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6
# Feature lh_bankssts_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 7
# Feature rh_bankssts_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 8
# Feature lh_caudalanteriorcingulate_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 9
# Feature rh_caudalanteriorcingulate_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 10
# Feature lh_caudalmiddlefrontal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 11
# Feature rh_caudalmiddlefrontal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 12
# Feature lh_cuneus_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 14
# Feature lh_entorhinal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 15
# Feature rh_entorhinal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 16
# Feature lh_fusiform_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 17
# Feature rh_fusiform_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 18
# Feature lh_inferiorparietal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 19
# Feature rh_inferiorparietal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 20
# Feature lh_inferiortemporal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 21
# Feature rh_inferiortemporal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 22
# Feature lh_isthmuscingulate_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 23
# Feature rh_isthmuscingulate_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 24
# Feature lh_lateraloccipital_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 25
# Feature rh_lateraloccipital_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 26
# Feature lh_lateralorbitofrontal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 27
# Feature rh_lateralorbitofrontal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 28
# Feature lh_lingual_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 29
# Feature rh_lingual_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 30
# Feature lh_medialorbitofrontal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 31
# Feature rh_medialorbitofrontal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 32
# Feature lh_middletemporal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 33
# Feature rh_middletemporal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 34
# Feature lh_parahippocampal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 35
# Feature rh_parahippocampal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 36
# Feature lh_paracentral_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 37
# Feature rh_paracentral_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 38
# Feature lh_parsopercularis_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 39
# Feature rh_parsopercularis_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 40
# Feature lh_parsorbitalis_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 41
# Feature rh_parsorbitalis_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 42
# Feature lh_parstriangularis_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 43
# Feature rh_parstriangularis_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 46
# Feature lh_postcentral_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 47
# Feature rh_postcentral_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 48
# Feature lh_posteriorcingulate_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 49
# Feature rh_posteriorcingulate_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 50
# Feature lh_precentral_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 51
# Feature rh_precentral_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 52
# Feature lh_precuneus_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 53
# Feature rh_precuneus_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 54
# Feature lh_rostralanteriorcingulate_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 55
# Feature rh_rostralanteriorcingulate_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 56
# Feature lh_rostralmiddlefrontal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 57
# Feature rh_rostralmiddlefrontal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 58
# Feature lh_superiorfrontal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 59
# Feature rh_superiorfrontal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 60
# Feature lh_superiorparietal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 61
# Feature rh_superiorparietal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 62
# Feature lh_superiortemporal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 63
# Feature rh_superiortemporal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 64
# Feature lh_supramarginal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 65
# Feature rh_supramarginal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 66
# Feature lh_frontalpole_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 67
# Feature rh_frontalpole_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 68
# Feature lh_temporalpole_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 69
# Feature rh_temporalpole_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 70
# Feature lh_transversetemporal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 71
# Feature rh_transversetemporal_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 72
# Feature lh_insula_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 73
# Feature rh_insula_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 74
# Feature lh_MeanThickness_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 75
# Feature rh_MeanThickness_thickness is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 76
# Feature BrainSegVolNotVent is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 78
# Feature Left-Lateral-Ventricle is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 79
# Feature Left-Inf-Lat-Vent is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 80
# Feature Left-Cerebellum-White-Matter is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 82
# Feature Left-Thalamus-Proper is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 84
# Feature Left-Putamen is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 85
# Feature Left-Pallidum is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 86
# Feature 3rd-Ventricle is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 87
# Feature 4th-Ventricle is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 88
# Feature Brain-Stem is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 89
# Feature Left-Hippocampus is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 90
# Feature Left-Amygdala is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 91
# Feature CSF is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 92
# Feature Left-Accumbens-area is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 93
# Feature Left-VentralDC is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 95
# Feature Left-choroid-plexus is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 96
# Feature Right-Lateral-Ventricle is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 97
# Feature Right-Inf-Lat-Vent is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 98
# Feature Right-Cerebellum-White-Matter is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 99
# Feature Right-Cerebellum-Cortex is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 100
# Feature Right-Thalamus-Proper is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 101
# Feature Right-Caudate is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 102
# Feature Right-Putamen is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 103
# Feature Right-Pallidum is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 104
# Feature Right-Hippocampus is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 105
# Feature Right-Amygdala is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 106
# Feature Right-Accumbens-area is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 107
# Feature Right-VentralDC is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 108
# Feature Right-vessel is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 109
# Feature Right-choroid-plexus is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 110
# Feature WM-hypointensities is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 111
# Feature Optic-Chiasm is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 114
# Feature CC_Central is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 115
# Feature CC_Mid_Anterior is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 117
# Feature lhCortexVol is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 118
# Feature rhCortexVol is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 120
# Feature SubCortGrayVol is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 121
# Feature MaskVol is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 122
# Feature BrainSegVol-to-eTIV is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 123
# Feature MaskVol-to-eTIV is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 124
# Feature lhSurfaceHoles is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 125
# Feature rhSurfaceHoles is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 126
# Feature Diagnosis is significantly different between AD and CTL groups
# /home/fathinah.izzati/miniconda3/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:563: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %%
print(f"Significant features: {len(significant_features)}")
# Out:
# Significant features: 116
