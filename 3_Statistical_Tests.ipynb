# %%
import pandas as pd
from scipy.stats import chi2_contingency 
from scipy import stats
import numpy as np
import statsmodels.stats.api as sms
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
data = pd.read_csv('data/gene_prot_data.csv')

# %%
data
# Out:
#     Subject_ID  Diagnosis        Age  APOE      MMSE  Sex     PC1      PC2  \
# 0     DCR00025          0  75.000000     0  moderate    0  0.0088   0.0276
# 1     DCR00028          0  88.000000     1  moderate    0  0.0114   0.0284
# 2     DCR00031          0  75.461386     0  moderate    0  0.0097  28.0000
# 3     DCR00032          0  75.461386     0  moderate    1  0.0076  28.0000
# 4     DCR00037          0  75.461386     2  moderate    1  0.0097   0.0244
# ..         ...        ...        ...   ...       ...  ...     ...      ...
# 512  THSMCI061          2  67.000000     1      high    1  0.0073  -0.0539
# 513  THSMCI064          2  80.000000     1      high    0  0.0135  -0.0574
# 514  THSMCI064          0  80.000000     1  moderate    0  0.0135  -0.0574
# 515  THSMCI065          2  76.000000     2      high    0  0.0011  -0.0498
# 516  THSMCI065          2  77.000000     2      high    0  0.0011  -0.0498
#
#          PC3     PC4  ...  xu.S6OENiSSCDruXFc  xu3n8ix_RpCpNPRKhc  \
# 0     0.0132  0.0005  ...            0.010746            0.424735
# 1     0.0192 -0.0095  ...            0.239652            0.297554
# 2    13.0000 -0.0234  ...            0.058596            0.438859
# 3     9.0000 -0.0011  ...            0.287620            0.579192
# 4    18.0000 -0.0043  ...            0.316210            0.422101
# ..       ...     ...  ...                 ...                 ...
# 512   0.0073  0.0216  ...            0.589071            0.961699
# 513  -0.0044 -2.0000  ...            0.663432            0.933129
# 514  -0.0044 -2.0000  ...            0.663432            0.933129
# 515   0.0126  0.0303  ...            0.659313            0.911345
# 516   0.0126  0.0303  ...            0.659313            0.911345
#
#      xuBm5ckgidWRNTl.gQ  xuNOUeR1JerhIuIV7c  xud4v2r3nXECBua55o  \
# 0              0.398869            0.066384            0.321479
# 1              0.341023            0.071577            0.429470
# 2              0.216219            0.599177            0.179004
# 3              0.211476            0.200429            0.001667
# 4              0.247895            0.154150            0.334002
# ..                  ...                 ...                 ...
# 512            0.622341            0.796417            0.776029
# 513            0.629757            0.826243            0.851986
# 514            0.629757            0.826243            0.851986
# 515            0.773895            0.843128            0.824156
# 516            0.773895            0.843128            0.824156
#
#      xvHfVEL1fC35XJ7neU  xve7nuGHtAizelOmhE  xvrrv4q_nIDgJej.uU  \
# 0              0.149548            0.095191            0.004099
# 1              0.233205            0.268920            0.158143
# 2              0.193932            0.098406            0.122535
# 3              0.218742            0.263119            0.261860
# 4              0.184145            0.304057            0.309619
# ..                  ...                 ...                 ...
# 512            0.823258            0.585026            0.371426
# 513            0.937715            0.710167            0.549367
# 514            0.937715            0.710167            0.549367
# 515            0.783705            0.709999            0.510799
# 516            0.783705            0.709999            0.510799
#
#      xws9e3UChad1OnXmXY  xz1S1tKD.sgqfTuesU
# 0              0.253679            0.000000
# 1              0.277040            0.361951
# 2              0.141998            0.263429
# 3              0.221761            0.162624
# 4              0.165162            0.385041
# ..                  ...                 ...
# 512            0.803298            0.525950
# 513            0.774187            0.639621
# 514            0.774187            0.639621
# 515            0.855688            0.716505
# 516            0.855688            0.716505
#
# [517 rows x 6244 columns]

# %% [markdown]
# ### 3. Statistical Tests

# %% [markdown]
# #### Chi Squared Tests

# %% [markdown]
# ##### H₀ — that the 2 categorical variables being compared are independent of each other (no association)
# ##### H₁ — that the 2 categorical variables being compared are dependent on each other (association).

# %% [markdown]
# ##### 1. Gender and AD Diagnosis

# %%
data['Sex'] = data['Sex'].replace({0:'Female', 1:'Male'})
data['Diagnosis'] = data['Diagnosis'].replace({0:'AD', 1:'CTL', 2:'MCI'})  

chi = pd.crosstab(data.Sex, data.Diagnosis,margins=True)
print(chi)

obs = np.array([chi.iloc[0][0:2].values,chi.iloc[1][0:2].values])
chi_squared = stats.chi2_contingency(obs, correction=False)
print("\n(X^2, p, df):",chi_squared[0:3])

print("\nConclusion:")
if(chi_squared[1] < 0.05):
    print("At 5% significance level, we fail to reject Ha which means there is sufficient evidence to suggest that there is an association between AD diagnosis and the gender feature")
else:
    print("At 5% significance level, we fail to reject Ho which means there is sufficient evidence to suggest that there is no association between AD diagnosis and the gender feature")
# Out:
# Diagnosis   AD  CTL  MCI  All
# Sex
# Female      84   57   55  196
# Male       164   85   72  321
# All        248  142  127  517
#
# (X^2, p, df): (1.537815592898336, 0.2149432428442663, 1)
#
# Conclusion:
# At 5% significance level, we fail to reject Ho which means there is sufficient evidence to suggest that there is no association between AD diagnosis and the gender feature

# %% [markdown]
# Given that the p-value is 0.2149432428442663, which is much higher than the common significance level of 0.05, we fail to reject the null hypothesis. This means there is not enough evidence to suggest that there is a statistically significant association between sex and diagnosis category in this sample.

# %% [markdown]
# ##### 2. APOE and AD Diagnosis

# %%
data['APOE'] = data['APOE'].replace({0:'E4E4', 1:'E3E3', 2:'E3E4', 3:'E2E3', 4:'E2E4'})
data['Diagnosis'] = data['Diagnosis'].replace({0:'AD', 1:'CTL', 2:'MCI'})  

chi = pd.crosstab(data.APOE, data.Diagnosis,margins=True)
print(chi)

obs = np.array([chi.iloc[0][0:2].values,chi.iloc[1][0:2].values])
chi_squared = stats.chi2_contingency(obs, correction=False)
print("\n(X^2, p, df):",chi_squared[0:3])

print("\nConclusion:")
if(chi_squared[1] < 0.05):
    print("At 5% significance level, we fail to reject Ha which means there is sufficient evidence to suggest that there is an association between AD diagnosis and the APOE feature")
else:
    print("At 5% significance level, we fail to reject Ho which means there is sufficient evidence to suggest that there is no association between AD diagnosis and the APOE feature")
# Out:
# Diagnosis   AD  CTL  MCI  All
# APOE
# E2E3        16   23   12   51
# E2E4         4    4    2   10
# E3E3       104   37   46  187
# E3E4        90   72   61  223
# E4E4        34    6    6   46
# All        248  142  127  517
#
# (X^2, p, df): (0.2187084520417853, 0.6400257800420942, 1)
#
# Conclusion:
# At 5% significance level, we fail to reject Ho which means there is sufficient evidence to suggest that there is no association between AD diagnosis and the APOE feature

# %% [markdown]
# ##### 3. MMSE and AD Diagnosis

# %%
#create new catgeory based on MMSE score: 0-0.25: very low, 0.25-0.5: low, 0.5-0.75: moderate, 0.75-1: high
data['MMSE_Cat'] = pd.cut(data['MMSE'], bins=[0,0.5,0.75,1], labels=['low','moderate','high'])

# %%
data['Diagnosis'] = data['Diagnosis'].replace({0:'AD', 1:'CTL', 2:'MCI'})  

chi = pd.crosstab(data.MMSE_Cat, data.Diagnosis,margins=True)
print(chi)

obs = np.array([chi.iloc[0][0:2].values,chi.iloc[1][0:2].values])
chi_squared = stats.chi2_contingency(obs, correction=True)
print("\n(X^2, p, df):",chi_squared[0:3])

print("\nConclusion:")
if(chi_squared[1] < 0.05):
    print("At 5% significance level, we fail to reject Ha which means there is sufficient evidence to suggest that there is an association between AD diagnosis and the MMSE score")
else:
    print("At 5% significance level, we fail to reject Ho which means there is sufficient evidence to suggest that there is no association between AD diagnosis and the MMSE score")
# Out:
# Diagnosis   AD  CTL  MCI  All
# MMSE_Cat
# low         97    0    4  101
# moderate    85    1   14  100
# high        65  141  109  315
# All        247  142  127  516
#
# (X^2, p, df): (0.0036461530557670577, 0.9518502922042056, 1)
#
# Conclusion:
# At 5% significance level, we fail to reject Ho which means there is sufficient evidence to suggest that there is no association between AD diagnosis and the MMSE score

# %% [markdown]
# ### Confidence Interval

# %% [markdown]
# #### 1. Gender and Diagnosis

# %%
#95% confidence interval for difference in mean
data['Sex'] = data['Sex'].replace({'Female':0, 'Male':1})
data['Diagnosis'] = data['Diagnosis'].replace({'AD':0, 'CTL':1, 'MCI':2})  
female = data.query('Sex == 0')
male = data.query('Sex == 1')

cm = sms.CompareMeans(sms.DescrStatsW(female['Diagnosis']), sms.DescrStatsW(male['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nGiven that the value of zero is included in the interval, this suggest that the means of the two population can be assumed equal as there is a difference between them. ")
# Out:
# Confidence Interval for u1-u2:  (-0.008010776829207589, 0.2853011322237019)
#
# Given that the value of zero is included in the interval, this suggest that the means of the two population can be assumed equal as there is a difference between them.

# %% [markdown]
# #### 2. APOE and Diagnosis

# %%
#95% confidence interval for difference in mean
data['APOE'] = data['APOE'].replace({'E4E4':0, 'E3E3':1, 'E3E4':2, 'E2E3':3, 'E2E4':4})
e4e4 = data.query('APOE == 0')
e3e3 = data.query('APOE == 1')
e3e4 = data.query('APOE == 2')
e2e3 = data.query('APOE == 3')

print("\nE4E4 vs E3E3")
cm = sms.CompareMeans(sms.DescrStatsW(e4e4['Diagnosis']), sms.DescrStatsW(e3e3['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nE4E4 vs E3E4")
cm = sms.CompareMeans(sms.DescrStatsW(e4e4['Diagnosis']), sms.DescrStatsW(e3e4['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nE4E4 vs E2E3")
cm = sms.CompareMeans(sms.DescrStatsW(e4e4['Diagnosis']), sms.DescrStatsW(e2e3['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nE3E3 vs E3E4")
cm = sms.CompareMeans(sms.DescrStatsW(e3e3['Diagnosis']), sms.DescrStatsW(e3e4['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nE3E3 vs E2E3")
cm = sms.CompareMeans(sms.DescrStatsW(e3e3['Diagnosis']), sms.DescrStatsW(e2e3['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nE3E4 vs E2E3")
cm = sms.CompareMeans(sms.DescrStatsW(e3e4['Diagnosis']), sms.DescrStatsW(e2e3['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))
# Out:
# E4E4 vs E3E3
# Confidence Interval for u1-u2:  (-0.541390023851572, -0.055680424881280804)
#
# E4E4 vs E3E4
# Confidence Interval for u1-u2:  (-0.7150975430506388, -0.24220407519853254)
#
# E4E4 vs E2E3
# Confidence Interval for u1-u2:  (-0.8243880437111856, -0.23614051553860105)
#
# E3E3 vs E3E4
# Confidence Interval for u1-u2:  (-0.341874553778563, -0.018356615737755516)
#
# E3E3 vs E2E3
# Confidence Interval for u1-u2:  (-0.4722810145422946, 0.008822904025360623)
#
# E3E4 vs E2E3
# Confidence Interval for u1-u2:  (-0.2856673902729793, 0.18244044927236386)

# %% [markdown]
# Based on the confidence intervals, the differences between certain APOE genotypes suggest the following for Alzheimer's disease (AD) diagnosis:
#
# - E4E4 vs E3E3: The confidence interval does not contain zero, indicating a statistically significant difference between these two genotypes for AD diagnosis. The E4E4 genotype appears to be associated with a higher risk of AD compared to E3E3.
# - E4E4 vs E3E4: The confidence interval does not contain zero, suggesting a significant difference between E4E4 and E3E4 genotypes for AD diagnosis. The E4E4 genotype likely has a higher risk of AD than E3E4.
# - E4E4 vs E2E3: The confidence interval does not contain zero, implying a significant difference between E4E4 and E2E3 genotypes. The E4E4 genotype is likely associated with a higher risk of AD compared to E2E3.
# - E3E3 vs E3E4: The confidence interval does not contain zero, indicating a significant difference between these genotypes for AD diagnosis. The E3E4 genotype may have a higher risk of AD than E3E3.
# - E3E3 vs E2E3 and E3E4 vs E2E3: The confidence intervals contain zero, suggesting no statistically significant difference between these genotype pairs for AD diagnosis.
#
#
# In summary, the presence of the E4 allele, particularly the E4E4 genotype, appears to be associated with a higher risk of Alzheimer's disease compared to other APOE genotypes like E3E3, E3E4, and E2E3.

# %% [markdown]
# #### 3. MMSE and AD

# %%
data['MMSE'] = pd.cut(data['MMSE'], bins=[0,0.25, 0.5,0.75,1], labels=['very low','low','moderate','high'])
very_low = data.query('MMSE == "very low"')
low = data.query('MMSE == "low"')
moderate = data.query('MMSE == "moderate"')
high = data.query('MMSE == "high"')

print("\nVery Low vs Low")
cm = sms.CompareMeans(sms.DescrStatsW(very_low['Diagnosis']), sms.DescrStatsW(low['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nVery Low vs Moderate")
cm = sms.CompareMeans(sms.DescrStatsW(very_low['Diagnosis']), sms.DescrStatsW(moderate['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nVery Low vs High")
cm = sms.CompareMeans(sms.DescrStatsW(very_low['Diagnosis']), sms.DescrStatsW(high['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nLow vs Moderate")
cm = sms.CompareMeans(sms.DescrStatsW(low['Diagnosis']), sms.DescrStatsW(moderate['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nLow vs High")
cm = sms.CompareMeans(sms.DescrStatsW(low['Diagnosis']), sms.DescrStatsW(high['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))

print("\nModerate vs High")
cm = sms.CompareMeans(sms.DescrStatsW(moderate['Diagnosis']), sms.DescrStatsW(high['Diagnosis']))
print("Confidence Interval for u1-u2: ", cm.tconfint_diff(usevar='unequal'))
# Out:
# Very Low vs Low
# Confidence Interval for u1-u2:  (-0.19517991106772828, -0.0023509531298025743)
#
# Very Low vs Moderate
# Confidence Interval for u1-u2:  (-0.4290096685427071, -0.15099033145729285)
#
# Very Low vs High
# Confidence Interval for u1-u2:  (-1.2207358907517094, -1.0586291886133699)
#
# Low vs Moderate
# Confidence Interval for u1-u2:  (-0.35938720431286864, -0.02308193148960047)
#
# Low vs High
# Confidence Interval for u1-u2:  (-1.1662836476249154, -0.915550567542633)
#
# Moderate vs High
# Confidence Interval for u1-u2:  (-1.0100960549637923, -0.6892690244012869)

# %% [markdown]
# Based on the confidence intervals comparing different MMSE score bands, this image suggests the following about the relationship between MMSE scores and Alzheimer's disease (AD) diagnosis:
#
# - Very Low vs Low: The confidence interval contains zero, indicating there may not be a statistically significant difference in AD diagnosis between the "Very Low" and "Low" MMSE score bands.
# - Very Low vs Moderate: The confidence interval does not contain zero, suggesting a statistically significant difference between the "Very Low" and "Moderate" MMSE bands for AD diagnosis. The "Very Low" band is likely associated with a higher risk of AD compared to the "Moderate" band.
# - Very Low vs High: The confidence interval does not contain zero, implying a significant difference between the "Very Low" and "High" MMSE bands in terms of AD diagnosis. The "Very Low" band is probably associated with a higher risk of AD compared to the "High" band.
# - Low vs Moderate: The confidence interval contains zero, indicating no statistically significant difference in AD diagnosis between the "Low" and "Moderate" MMSE bands.
# - Low vs High: The confidence interval does not contain zero, suggesting a significant difference between the "Low" and "High" MMSE bands for AD diagnosis. The "Low" band is likely associated with a higher risk of AD compared to the "High" band.
# - Moderate vs High: The confidence interval does not contain zero, implying a significant difference between the "Moderate" and "High" MMSE bands in terms of AD diagnosis. The "Moderate" band is probably associated with a higher risk of AD compared to the "High" band.
#
#
# In summary, lower MMSE scores, particularly in the "Very Low" and "Low" bands, appear to be associated with a higher risk of Alzheimer's disease compared to higher MMSE scores in the "Moderate" and "High" bands.

# %% [markdown]
# ### Hypothesis Testing

# %%
data = pd.read_csv('data/gene_prot_data.csv')

# %%
import pandas as pd
from scipy import stats

data_no_key = data.drop(columns=['Subject_ID'])
ad = data_no_key.query('Diagnosis == 0')
ctl = data_no_key.query('Diagnosis == 1')
# Perform an independent t-test 
t_stat, p_val = stats.ttest_ind(ad, ctl, axis=0)

significant_features = []
# Iterate over the T-statistics and P-values to print out results for each comparison
for i, (t, p) in enumerate(zip(t_stat, p_val)):
    # print(f"Comparison {i}: T-statistic = {t}, P-value = {p}")
    if p < 0.05:
        print(f"  -> Significant difference detected at comparison {i}")
        print(f"Feature {data_no_key.columns[i]} is significantly different between AD and CTL groups")
        significant_features.append(data_no_key.columns[i])
# Out:
#   -> Significant difference detected at comparison 0
# Feature Diagnosis is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1
# Feature Age is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 2
# Feature APOE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 3
# Feature MMSE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 12
# Feature PC8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 19
# Feature P01033 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 24
# Feature P48061 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 26
# Feature P35916 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 27
# Feature P01031 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 30
# Feature P11362 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 47
# Feature Q15768 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 48
# Feature O00451 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 54
# Feature P18065 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 60
# Feature P01236 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 62
# Feature Q01973 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 66
# Feature O15123 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 69
# Feature O75462,Q9UBD9 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 77
# Feature Q15303 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 78
# Feature P09758 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 81
# Feature P03129 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 92
# Feature P22897 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 96
# Feature P22223 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 100
# Feature P32942 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 101
# Feature Q03405 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 103
# Feature P19438 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 109
# Feature P13385 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 110
# Feature P00533 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 119
# Feature P14555 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 121
# Feature P16284 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 126
# Feature O15444 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 129
# Feature P26992 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 131
# Feature P19235 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 140
# Feature Q13253 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 141
# Feature P48745 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 148
# Feature Q9BZM4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 156
# Feature O95990 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 163
# Feature P18093 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 180
# Feature P04114 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 188
# Feature P33151 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 221
# Feature Q05655 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 225
# Feature P11387 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 229
# Feature P10643 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 233
# Feature Q16627 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 236
# Feature P55773 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 246
# Feature P41271 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 249
# Feature P10912 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 264
# Feature P18075 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 265
# Feature P16671 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 273
# Feature P09341 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 277
# Feature P01579 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 293
# Feature P08697 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 296
# Feature P55773.1 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 303
# Feature Q9UHD0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 310
# Feature P55774 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 313
# Feature P07477 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 314
# Feature P04275 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 318
# Feature P24394 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 339
# Feature Q9UMR2 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 350
# Feature P35475 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 360
# Feature P07339 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 364
# Feature P06681 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 374
# Feature P22304 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 378
# Feature P09960 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 392
# Feature P13686 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 393
# Feature Q76M96 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 413
# Feature P12318 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 425
# Feature Q14114 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 427
# Feature O00339 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 430
# Feature O75594 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 435
# Feature P35442 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 446
# Feature P23280 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 452
# Feature Q9UJ71 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 453
# Feature Q9BU40 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 458
# Feature Q9UGM5 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 462
# Feature P49862 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 467
# Feature P05154 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 474
# Feature Q8WWQ8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 484
# Feature P21815 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 487
# Feature Q13557 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 509
# Feature Q13950 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 511
# Feature Q96GW7 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 520
# Feature P35030 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 526
# Feature O43927 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 535
# Feature P56199,P05556 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 551
# Feature Q15848 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 552
# Feature P01009 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 553
# Feature P02765 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 554
# Feature P15289 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 555
# Feature P35613 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 558
# Feature P55285 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 559
# Feature Q14012 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 561
# Feature P14091 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 562
# Feature Q13231 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 563
# Feature O00533 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 565
# Feature Q96KN2 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 568
# Feature Q9UBP4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 576
# Feature Q99538 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 587
# Feature P05129 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 589
# Feature P02753 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 593
# Feature P42680 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 595
# Feature Q8TEU8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 603
# Feature P11717 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 611
# Feature P24298 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 616
# Feature P46527 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 646
# Feature Q9NQ30 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 674
# Feature O95571 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 676
# Feature P25685 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 716
# Feature P36222 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 722
# Feature P13671 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 723
# Feature O00175 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 728
# Feature P10144 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 733
# Feature Q9NYY1 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 737
# Feature P01042 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 744
# Feature P00747.1 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 747
# Feature P07288,P01011 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 794
# Feature Q9HCB6 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 806
# Feature P02735 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 808
# Feature P05362 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 828
# Feature O75356 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 838
# Feature O15530 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 843
# Feature Q7LFX5 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 845
# Feature P07951 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 849
# Feature P05155 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 857
# Feature P05231 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 859
# Feature P29460,Q9NPF7 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 861
# Feature P39900 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 862
# Feature P13591 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 864
# Feature Q9Y240.1 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 866
# Feature Q9GZN4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 870
# Feature P10909 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 875
# Feature Q9NZU1 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 877
# Feature Q11128 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 894
# Feature P01298 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 896
# Feature P18509.1 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 897
# Feature P31937 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 906
# Feature P08700 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 912
# Feature Q92484 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 920
# Feature Q14624 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 925
# Feature P09919 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 930
# Feature Q16620 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 934
# Feature P00740 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 935
# Feature P00740.1 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 939
# Feature P80098 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 944
# Feature P01024.6 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 967
# Feature P52823 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 975
# Feature Q9NZ08 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 985
# Feature P19957 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 989
# Feature Q05397 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 994
# Feature P28799 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1013
# Feature Q13093 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1017
# Feature Q15181 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1021
# Feature P23396 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1023
# Feature Q12884 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1030
# Feature P98066 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1031
# Feature 0..gjSdbqnr.rUSTBI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1032
# Feature 0.PRu.vXrqQjlN4p9I is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1033
# Feature 00K3OeGXV631V5_6eA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1034
# Feature 00buPhOysV5Rpc5VF4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1035
# Feature 0106ep0.a1f3X61SF8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1036
# Feature 01BXNAw4H3SIpN6rXo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1037
# Feature 01QpEiEak1_HU2pn38 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1038
# Feature 01S9SfXAMhLqzakktE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1039
# Feature 01ScdqKeKeijZ_LUos is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1040
# Feature 01Tv.FeVeX48h1yRek is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1041
# Feature 01YintXoV6ek6AxLqA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1042
# Feature 01kigeOLuQ_IkyS6SU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1043
# Feature 0255m6FSUH9Z5w1Lv0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1044
# Feature 02tiuhr_lsCu6c8E64 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1045
# Feature 03_TFU7fVS_1Xov6qg is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1046
# Feature 03kIj3koHq7kRrvslI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1047
# Feature 03pfnDpBIICp9.m61U is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1048
# Feature 04.BQghp5olySHSl7o is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1049
# Feature 04RV5U.3t.DwUK7yu4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1050
# Feature 04TlFWDp0f0eKOe13g is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1051
# Feature 04qkX6fWXucn_U7Teg is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1052
# Feature 05.K._ASVaYZdz6d2k is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1053
# Feature 053WgoPev2bjXl5tbs is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1054
# Feature 055155VOJ7lC7lSp5M is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1055
# Feature 0576touUtHn_gt7veo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1056
# Feature 05B2nveh3ju7oqOqDI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1057
# Feature 05Fewg6HwCx56EpO7k is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1058
# Feature 05GRvqiC2lfqN.d_LQ is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1059
# Feature 05UqSufN4XwS53TTro is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1060
# Feature 05VLSnQle6_ygwJe40 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1061
# Feature 05a52iCJku.5C56Ldc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1062
# Feature 06CvPSuaE8UG7kqObU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1063
# Feature 06Qp9fW781eyU0.C0o is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1064
# Feature 06Xqf3il83jl3kvTtU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1065
# Feature 06iniuro0ei.iFFelA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1066
# Feature 07NyfWpQhJ06SKXQik is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1067
# Feature 07fRpJv_dESSf_RlUo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1068
# Feature 07jk11aXl4leOee0iA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1069
# Feature 07lY5uVChBlPCA9tPY is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1070
# Feature 07pmZey1Scf6KeKQig is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1071
# Feature 07riWI_RT5ncl6kEEk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1072
# Feature 07rojh4JWEaXibUgOs is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1073
# Feature 07yvMP3T_iWpkunRl4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1074
# Feature 08X9Hd6eereW2teecE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1075
# Feature 097eBEJe9y16aBEeqs is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1076
# Feature 09Jkl_l2qSepVdO5S8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1077
# Feature 09NJWUI6Y5CaUIqYE8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1078
# Feature 09kidveWWSQwJ1.lmA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1079
# Feature 09tew3v3K4JMdS7.Ko is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1080
# Feature 0AmKRHnx5fqvuiOhW4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1081
# Feature 0B2unl2eOJ63mNeDqo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1082
# Feature 0B7ko6J3jAmRCudASk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1083
# Feature 0C3Sunm7rp05ew1QT0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1084
# Feature 0CBX4XqmwwI4XoVeVU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1085
# Feature 0CU36wP1UEu4LyD19I is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1086
# Feature 0CVF5Bd7Sy3t4N.FL0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1087
# Feature 0DJ9t0v1UAqsVKVdd4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1088
# Feature 0E90qLerOeoA0lI5a4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1089
# Feature 0EAxQt1XfTqALrg1RU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1090
# Feature 0ECqTqXUl.lRC5dLlQ is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1091
# Feature 0EbCMSt83Xjru1P_Xo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1092
# Feature 0Eg4IC0qoeQKUO_uek is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1093
# Feature 0EmU3dXiDAljJRddac is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1094
# Feature 0F8Fl88lI_7XU0efV4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1096
# Feature 0I66_TqfXq3Ud1t6XA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1097
# Feature 0ICkSh2cLvZxmqcWjY is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1098
# Feature 0IiH14JJlUUJ0Il01k is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1099
# Feature 0J53x7JOuXTsBUR6Jg is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1100
# Feature 0JJmKUi1DAdudN5Jdc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1101
# Feature 0JKeqmnnvi3v.HtyeU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1102
# Feature 0JQL13K1YLbpKKK2rA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1103
# Feature 0JXnkCOtBsXAFYIF94 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1104
# Feature 0Je9NYkuakxBriB6IE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1105
# Feature 0Ju3s.O7iieen5Lmbk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1106
# Feature 0KI6VQQkVZ.5JIoni8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1107
# Feature 0KIa4XUlSodeXdXvd0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1108
# Feature 0KVgI1U009lvF5SOok is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1109
# Feature 0KWCUmVJ.XR717oo7c is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1110
# Feature 0KpKj9199_tenVCp94 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1111
# Feature 0L0eFF20IVEUi3W5Jo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1112
# Feature 0L102EIGnm64JnGhU4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1113
# Feature 0LVKFITVSHUSOw4LVY is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1114
# Feature 0Lt45pR09p1Ug9ch6s is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1115
# Feature 0N_dK6StSaAuN5NVAI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1116
# Feature 0Nwe7usF_bRonvLgYo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1117
# Feature 0OBL955Jp6SGqU2F3M is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1118
# Feature 0OiSehnjroVeTEb3qQ is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1119
# Feature 0Op.O5yP8M1_JepC5E is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1120
# Feature 0PHsTIiErqT.6nF69s is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1121
# Feature 0PSNafoSkXiOuUC5J4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1122
# Feature 0PtPXs9FbUhfvRHdE4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1123
# Feature 0R3_RHfu..nR7RPVJE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1124
# Feature 0RQIdqIHoCnt6rfeHk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1125
# Feature 0RcpneulfkglcLGvHw is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1126
# Feature 0Ru4E3t_tEiernlrRc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1127
# Feature 0S0pqflO97g3YuJrlE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1128
# Feature 0S1_hT3jUvRSyvoSTM is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1129
# Feature 0SFQn1Or7x7nsUfrq0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1130
# Feature 0SKUYTAD0tX_19VuXU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1131
# Feature 0SSxd.hZflRiPgkeC0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1132
# Feature 0SU5CShIOuHq5X64ns is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1134
# Feature 0SXIRSwd_70UoVIV_k is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1135
# Feature 0SXhieViujBeEehqDU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1136
# Feature 0SXouANerHh.iKLi7k is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1137
# Feature 0Si_60s7deRJ6gUY3E is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1138
# Feature 0Sjik.leSjsVe23vtY is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1139
# Feature 0SnH9bU7F5ALapCG7U is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1140
# Feature 0SpIF3ghlHXUJfRXug is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1141
# Feature 0SteudjrYpTdetZemk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1142
# Feature 0Svv6Xd61N_pPK91JI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1143
# Feature 0To4rSdft56ulXlPeA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1144
# Feature 0ToUX6jFkkU0E1l_eM is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1145
# Feature 0Tqer.ufHs76YfrKko is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1146
# Feature 0U17LMrDovqoJJ9T3o is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1147
# Feature 0U4fRITrcg3sV8VEzg is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1148
# Feature 0U7o.6q1f_7dVZT0KE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1149
# Feature 0UJD25LqOJx.lJyKWU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1150
# Feature 0Ubt3qoc4DUY6jgXok is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1151
# Feature 0Uu3XrB6Bd14qoNeuc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1152
# Feature 0Uvp50qIjnc3px2zYE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1153
# Feature 0V.iL1ELrLIuvwbf10 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1154
# Feature 0V5eeeqiOe1O.cqs9M is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1155
# Feature 0VIE_Rjl14U5SLDdJ8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1156
# Feature 0VIQl.rqgSBdZNuy.4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1157
# Feature 0VSdUlXUCPx.VNbh14 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1158
# Feature 0VTluKu6Ho4EK46Rv0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1159
# Feature 0VUoQQHlfCLT9fvNEo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1160
# Feature 0VYLNK7XdM9eVXtLoE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1161
# Feature 0VqIAho6SjUKpyej_8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1162
# Feature 0VxRQHTYShYtXAWdTI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1163
# Feature 0WORJBSUNee3QqzWxc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1164
# Feature 0WoRH2mLnwXF1QRTzo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1165
# Feature 0XHqK6hV.T.S.503Kg is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1166
# Feature 0XUbj1xJL0JZokUIro is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1167
# Feature 0Xe.BLX6FPeNS9FLK8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1168
# Feature 0Xgknpy6fPH7h6F3rU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1169
# Feature 0XlXNHLk57pSEjhF.4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1170
# Feature 0Xn_ie7DpJgE7J7f70 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1171
# Feature 0YqYgjRTwQoRQrFQ5c is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1173
# Feature 0Z19P0rx299JC_kASE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1174
# Feature 0Z7unqF.KAuA5K4ggU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1175
# Feature 0ZqCOmgSnFC1ue.u7c is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1176
# Feature 0_DHz7_krTURH3lVHk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1177
# Feature 0_WFiq6EEf_SOJ66J0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1178
# Feature 0aENn6FSiuivkuJQDY is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1179
# Feature 0aZXcBf5XN7_RC_S7k is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1180
# Feature 0aj4oK1kSXt3nS_QwE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1181
# Feature 0ap5HlFepB9lClF.jk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1182
# Feature 0bECSHlZA2FrrAkVKA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1183
# Feature 0bRTzA98vSp6ma6dOU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1184
# Feature 0cn1ftaKM8A5yrivyU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1185
# Feature 0dVAtCQiHL4Ki96pSk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1186
# Feature 0dWhfTRT6ISAf4rop4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1187
# Feature 0e.hddVd584KrJOPe4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1188
# Feature 0e0o6rfXT7Km8o75.c is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1189
# Feature 0e5.F1_V_7dK7rV5ec is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1190
# Feature 0e5JLp3u7A5zkeKMRA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1191
# Feature 0e6Eq5J3FL17994lIU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1192
# Feature 0eE_BUvnSrSVPfH1eo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1193
# Feature 0efeTSfUHUXgS1YklI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1195
# Feature 0epFCF9XQSKEeJUGi8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1196
# Feature 0epSD9AaXRyn3r45e4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1197
# Feature 0eqkpnufe4rr8n.n9g is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1198
# Feature 0evfS558c.6wepf36o is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1199
# Feature 0fXrQnzrnz.jepR9XU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1200
# Feature 0fljnVJ4MCV5fcQdLs is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1201
# Feature 0flyIEROp.olYSF6n4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1202
# Feature 0ft07bSUkUJfvqRzSo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1203
# Feature 0g5fdUu53VQTXKRJ.Q is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1204
# Feature 0gLsZQcKhUQJKSKw5I is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1205
# Feature 0gSeUiYnk4gsTnnuTk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1206
# Feature 0gZMaTvDh3jrtdd6kk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1207
# Feature 0gveZObpFP1bgRU6is is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1208
# Feature 0hBxiSlaC4J6CEo0rk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1209
# Feature 0hDp_BeopIr7LieI6o is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1210
# Feature 0hLjntvRWEBHh9xNro is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1212
# Feature 0hVSs_3.hNSS1Cs_IQ is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1213
# Feature 0iDR_NUopor5LieI24 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1214
# Feature 0iS9nXV4wi_1QKtnwo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1215
# Feature 0igIDypdd43dnN5q14 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1216
# Feature 0iieSPJyqEnoPOen3g is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1217
# Feature 0inwpk7pEUdfUkstn8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1218
# Feature 0iquAFsl.k93Ml3kiI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1220
# Feature 0itKL0AUl6UE6YDXt4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1221
# Feature 0j14cFXd8icSYnk8Uk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1222
# Feature 0j5UW31IRVF4qqRSvw is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1223
# Feature 0jF7DVJxuop4rqIPn0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1224
# Feature 0jKVfXiX67V6DigI90 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1225
# Feature 0jUFQqQqTXqA5TQugc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1226
# Feature 0k1de_ckl.4XN5Dku8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1227
# Feature 0k7uZulu3uz9xu7Z30 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1228
# Feature 0k9.tSbh87FSAgpd.k is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1229
# Feature 0k9AKLpXv97vAFU.rk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1230
# Feature 0kSSZTf1v0qvuOClCg is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1231
# Feature 0kVQIHjSqlTOn2K_gI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1232
# Feature 0k_6fdLp_Ek316_zuk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1233
# Feature 0ki1IanvjdHl7K_CdI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1234
# Feature 0kiEgQfbMoWx16EU.U is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1235
# Feature 0kneCOQLirZ7eVPjIo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1236
# Feature 0ko95AO7dFRx4j70lU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1237
# Feature 0kqjYT4hQjkbWfXwTo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1238
# Feature 0kuM6SCEUiSOSIlP_4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1239
# Feature 0lB.jRJ1KFLkp6eV38 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1240
# Feature 0lEaClSj.T6eFZ3DOw is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1241
# Feature 0lOwqJTfoJI11JdS0I is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1242
# Feature 0lQqAgCgp33VSL1U5I is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1243
# Feature 0lzjRfk6EkNewE0SLo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1244
# Feature 0mV7gXjqBd3uEV1u98 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1245
# Feature 0nF7rjdku6ojstSECE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1246
# Feature 0nU0rkqj_ngpuTP16k is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1247
# Feature 0nXnkFnuDnniBdXc6o is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1248
# Feature 0nhUk0lEd6voA7_Xvo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1249
# Feature 0niXHt19Ue1.dSldI4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 1250
# ...
#   -> Significant difference detected at comparison 6125
# Feature x_iA44nGX44CBbvrnk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6126
# Feature xa8KoVExS5Qqo7QuuM is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6127
# Feature xaRtfpt3Dt5J0KnpH8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6128
# Feature xafXuefu0DoF5XcCR8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6129
# Feature xc.ko4vqSoAq0q9NK4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6130
# Feature xc2W1X.kld3qjoerA4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6131
# Feature xdJKfoRema1IRLkhN4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6132
# Feature xdNd1ECyFd1iVFJRIM is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6133
# Feature xdSXqYSLiHU36qgALM is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6134
# Feature xddfF_OHOqIWFKh0ho is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6135
# Feature xde7_T16j810Lk.eFM is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6136
# Feature xdf1USSf39e0HICiSg is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6137
# Feature xe0Ukf_FC15x5pV5XI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6138
# Feature xe7erFd4spcw9cX4e4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6139
# Feature xeAipIz6tfuH0Hh31g is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6140
# Feature xeEedZNee7te9TvWvU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6142
# Feature xeSJevQDS0dX0gkhOk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6143
# Feature xeunif.VJKDq12DTbk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6145
# Feature xfV.5pTRYJqJpQDgvw is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6146
# Feature xfcujvkdAankiOifSk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6147
# Feature xfe6UjfjT0FLDrF4oE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6148
# Feature xg3S30l5Hj_yXke3x4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6149
# Feature xgfcSCUJ1eiV76Sdyc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6150
# Feature xgiWrpJ4SKCWdAxfRA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6151
# Feature xh763crJf63PsRDdP0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6152
# Feature xhTWAXm1euO90JdoLo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6153
# Feature xheHUd8BerfdfprntI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6154
# Feature xhfxSSl1UUjleZ6MXA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6155
# Feature xhqv9fnXlKPALU4v34 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6156
# Feature xi1KL_IUl6kECYhXt8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6157
# Feature xiStt5q_gBQIFK40ec is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6158
# Feature xiVNJ5Rl6BChZFSPlM is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6159
# Feature xiaOf05Ffx5H94UonE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6160
# Feature xifcAeg4Sg6XXV8nV4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6161
# Feature xiz6Qn5S7F5a7p7pTc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6162
# Feature xjDwAHrqk765EXutUk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6163
# Feature xjEtHB9N7VblX1SteU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6164
# Feature xjeW0eq6QTXq1wt7p0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6165
# Feature xjgDpC9Xp.X3nQf07c is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6166
# Feature xjhF.ile5NiW.1JWUg is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6167
# Feature xjpUt9zVUXACFCT45U is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6168
# Feature xjq9LrOJIoIjVIyyUs is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6169
# Feature xkbuzUN5e4Tk.x3_SI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6170
# Feature xkcLXk9e8CUfq0wgqI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6171
# Feature xkhAF34BX1VOkQHZU4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6172
# Feature xknTSEJRSuU9ASL6ro is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6174
# Feature xl68XtOg55Lrr_UJ94 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6175
# Feature xl7UnV3VQgEE4OJB9I is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6176
# Feature xlBPS3rO4pubgkIHXo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6177
# Feature xlG8TQRok6KS0p2PX8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6178
# Feature xlUrqDXz_nyh41H1O8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6179
# Feature xleUhmcj13Ct3iORb8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6180
# Feature xlwoJS0X3qQqdc39dU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6181
# Feature xlyunxSVC1U7_h.SeE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6182
# Feature xm4AHvjJJCIKkktvU0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6183
# Feature xm60reewT9UUHd_e1E is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6184
# Feature xmCeoSv3n0EUIgFh5o is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6185
# Feature xmKeUSKOgO18JkleL4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6186
# Feature xmX900n31irhK4CFXE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6187
# Feature xn4gFxP6EOIp515peY is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6188
# Feature xnL3utKaRQ4gKDkhXU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6189
# Feature xnUO7kn_Byp6r7q5d8 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6190
# Feature xnl116e._5e.gnHnl0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6191
# Feature xnlUuzt_X3WbT76CKI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6192
# Feature xnlXiCIfDUJePscuk0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6193
# Feature xnr4AsUdUd4E3pbV5A is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6194
# Feature xnrgFWCNBGfQHSVfoE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6195
# Feature xnrnj5EYbo1TYnr7fc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6196
# Feature xntytbWu7SP9dI8juU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6197
# Feature xoB14Cd3p6C14x4N1I is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6198
# Feature xoPL61ce1VOK_4FXVU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6199
# Feature xoT3o8_9ST5EtUcBfs is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6200
# Feature xoaLvFbgVI0Ug8LlYE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6201
# Feature xochUjffiKUjnUuXjo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6202
# Feature xodSVMJHu1XfTItdTw is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6203
# Feature xoigxw81PX.pXkk7Tk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6204
# Feature xoleNeUeR1JWphIuIU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6205
# Feature xorMF.VUSF4ie5f9zk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6206
# Feature xou.H_XUfe9dVleuec is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6207
# Feature xoupLtVvFLtJN3uLpM is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6208
# Feature xp0UixUgg0s6DyKEuk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6209
# Feature xp59et6So6v5.oDXco is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6210
# Feature xpBLlSp3ju3dGm4C7g is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6211
# Feature xpL_1VSfazl9KgK0Sc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6212
# Feature xpOSfuuLHvcoelADqQ is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6213
# Feature xpTRqDotTnICJ0u_p4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6214
# Feature xpa.LhVOHxJa98XfK4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6215
# Feature xpnTdFnegOdFl9l1RM is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6216
# Feature xq0V4Ug4Eqc8fKN7pQ is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6217
# Feature xq1zrrU_dIe01010ek is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6218
# Feature xqAt4uAo6XT3f3Dfno is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6219
# Feature xqBV_4k50s0_6IFCKk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6220
# Feature xqF579cmSU7jxXerdI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6221
# Feature xqfqgaC.N_jFfginq0 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6222
# Feature xqk3l6LxfU06cXnuv4 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6223
# Feature xqkU.S7AJLXHfURygo is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6224
# Feature xqn6O_R5VHl7V96wDA is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6225
# Feature xrFTlV5XZeg0u8eTeM is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6226
# Feature xreS6Je9l3DJS.Ekfk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6227
# Feature xreslBB_kH1HX3RduI is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6228
# Feature xrnReqXU1SCZKnz.3g is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6229
# Feature xsHVVKxjKh4M6FeeAk is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6230
# Feature xt.it_o4NIDc1Kc31I is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6231
# Feature xt5JSXnYB.LaXjp8ig is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6232
# Feature xtPfn5H1XPhE4Ce764 is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6233
# Feature xu.S6OENiSSCDruXFc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6234
# Feature xu3n8ix_RpCpNPRKhc is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6235
# Feature xuBm5ckgidWRNTl.gQ is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6236
# Feature xuNOUeR1JerhIuIV7c is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6237
# Feature xud4v2r3nXECBua55o is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6238
# Feature xvHfVEL1fC35XJ7neU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6239
# Feature xve7nuGHtAizelOmhE is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6240
# Feature xvrrv4q_nIDgJej.uU is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6241
# Feature xws9e3UChad1OnXmXY is significantly different between AD and CTL groups
#   -> Significant difference detected at comparison 6242
# Feature xz1S1tKD.sgqfTuesU is significantly different between AD and CTL groups
# /var/folders/gm/kc8nz1bj44z5q280b2p_5pxc0000gn/T/ipykernel_40175/2510018546.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_stat, p_val = stats.ttest_ind(ad, ctl, axis=0)

# %%
print(f"Significant features: {len(significant_features)}")
# Out:
# Significant features: 5230
